# %%
import os
print(os.getcwd())
# Out:
# /Users/apple/Desktop/bluestock_mf_capstone/notebooks

# %%
import pandas as pd

fund = pd.read_csv("../data/raw/01_fund_master.csv")

print(fund["fund_house"].unique())
print(fund["category"].unique())
print(fund["sub_category"].unique())
print(fund["risk_category"].unique())
# Out:
# <StringArray>
# [         'SBI Mutual Fund',         'HDFC Mutual Fund',
#       'ICICI Prudential MF',          'Nippon India MF',
#         'Kotak Mahindra MF',         'Axis Mutual Fund',
#  'Aditya Birla Sun Life MF',          'UTI Mutual Fund',
#            'Mirae Asset MF',          'DSP Mutual Fund']
# Length: 10, dtype: str
# <StringArray>
# ['Equity', 'Debt']
# Length: 2, dtype: str
# <StringArray>
# [      'Large Cap',       'Small Cap',            'Gilt',         'Mid Cap',
#   'Short Duration',           'Value',          'Liquid',       'Index/ETF',
#        'Flexi Cap',           'Index', 'Large & Mid Cap',            'ELSS']
# Length: 12, dtype: str
# <StringArray>
# ['Moderate', 'Very High', 'Low', 'High', 'Moderately High']
# Length: 5, dtype: str

# %%
fund = pd.read_csv("../data/raw/01_fund_master.csv")
nav = pd.read_csv("../data/raw/02_nav_history.csv")

missing_codes = set(fund["amfi_code"]) - set(nav["amfi_code"])

print("Missing AMFI Codes:")
print(missing_codes)

print("Number Missing:", len(missing_codes))
# Out:
# Missing AMFI Codes:
# set()
# Number Missing: 0

# %% [markdown]
# # Data Quality Report
#
# 1. Loaded all 10 datasets successfully.
# 2. Verified dataset structures and column types.
# 3. Checked fund master data.
# 4. Validated AMFI codes against NAV history.
# 5. No missing AMFI codes found.
# 6. Data ingestion completed successfully.
